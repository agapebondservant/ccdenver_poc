# %% [markdown]
# <div style="background-color: #ADD8E6; border: 1px solid gray; padding: 3px">
#     This notebook consists of 2 agentic workflows:
#         <h3>Data Generation Workflow</h3>
#         <li><b>Data Augmentation</b>: Augments the provided image dataset.</li>
#         <h3>Validation Workflow</h3>
#         <li><b>Image Validator</b>: Identifies whether a valid driver's license exists in the given image.</li>
#         <li><b>Data Extractor</b>: Extracts relevant metadata from the image.</li>
#         <li><b>Application Validator</b>: Given the extracted metadata associated with the application, uses a set of predefined rules to validate the driver's license application.</li>
# </div>

# %%
##############################################################################
# Imports
##############################################################################
import pysqlite3 as sqlite3
import sys
sys.modules['sqlite3'] = sys.modules.pop('pysqlite3')
from crewai import Agent, Task, Crew, Process, LLM
from crewai.project import CrewBase, agent, crew, task
from crewai.agents.agent_builder.base_agent import BaseAgent
from typing import List, Optional
from pydantic import Field, BaseModel
from crewai_tools import SerperDevTool
from crewai.tools import tool
from crewai.flow.flow import Flow, listen, start
from crew import ValidateDriversLicense
import os
from urllib.parse import urlparse
from dotenv import load_dotenv
load_dotenv()
import base64
import json
import asyncio
import nest_asyncio
nest_asyncio.apply()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 7
#       5 import sys
#       6 sys.modules['sqlite3'] = sys.modules.pop('pysqlite3')
# ----> 7 from crewai import Agent, Task, Crew, Process, LLM
#       8 from crewai.project import CrewBase, agent, crew, task
#       9 from crewai.agents.agent_builder.base_agent import BaseAgent
#
# File /opt/app-root/lib64/python3.11/site-packages/crewai/__init__.py:6
#       3 import warnings
#       4 from typing import Any
# ----> 6 from crewai.agent import Agent
#       7 from crewai.crew import Crew
#       8 from crewai.crews.crew_output import CrewOutput
#
# File /opt/app-root/lib64/python3.11/site-packages/crewai/agent.py:20
#      17 from pydantic import Field, InstanceOf, PrivateAttr, model_validator
#      19 from crewai.agents import CacheHandler
# ---> 20 from crewai.agents.agent_builder.base_agent import BaseAgent
#      21 from crewai.agents.crew_agent_executor import CrewAgentExecutor
#      22 from crewai.knowledge.knowledge import Knowledge
#
# File /opt/app-root/lib64/python3.11/site-packages/crewai/agents/agent_builder/base_agent.py:22
#      20 from crewai.agents.cache.cache_handler import CacheHandler
#      21 from crewai.agents.tools_handler import ToolsHandler
# ---> 22 from crewai.knowledge.knowledge import Knowledge
#      23 from crewai.knowledge.knowledge_config import KnowledgeConfig
#      24 from crewai.knowledge.source.base_knowledge_source import BaseKnowledgeSource
#
# File /opt/app-root/lib64/python3.11/site-packages/crewai/knowledge/knowledge.py:6
#       2 from typing import Any
#       4 from pydantic import BaseModel, ConfigDict, Field
# ----> 6 from crewai.knowledge.source.base_knowledge_source import BaseKnowledgeSource
#       7 from crewai.knowledge.storage.knowledge_storage import KnowledgeStorage
#       8 from crewai.rag.types import SearchResult
#
# File /opt/app-root/lib64/python3.11/site-packages/crewai/knowledge/source/base_knowledge_source.py:7
#       4 import numpy as np
#       5 from pydantic import BaseModel, ConfigDict, Field
# ----> 7 from crewai.knowledge.storage.knowledge_storage import KnowledgeStorage
#      10 class BaseKnowledgeSource(BaseModel, ABC):
#      11     """Abstract base class for knowledge sources."""
#
# File /opt/app-root/lib64/python3.11/site-packages/crewai/knowledge/storage/knowledge_storage.py:7
#       4 from typing import Any, cast
#       6 from crewai.knowledge.storage.base_knowledge_storage import BaseKnowledgeStorage
# ----> 7 from crewai.rag.chromadb.config import ChromaDBConfig
#       8 from crewai.rag.chromadb.types import ChromaEmbeddingFunctionWrapper
#       9 from crewai.rag.config.utils import get_rag_client
#
# File /opt/app-root/lib64/python3.11/site-packages/crewai/rag/chromadb/config.py:16
#       9 from pydantic.dataclasses import dataclass as pyd_dataclass
#      11 from crewai.rag.chromadb.constants import (
#      12     DEFAULT_DATABASE,
#      13     DEFAULT_STORAGE_PATH,
#      14     DEFAULT_TENANT,
#      15 )
# ---> 16 from crewai.rag.chromadb.types import ChromaEmbeddingFunctionWrapper
#      17 from crewai.rag.config.base import BaseRagConfig
#      19 warnings.filterwarnings(
#      20     "ignore",
#      21     message=".*Mixing V1 models and V2 models.*",
#      22     category=UserWarning,
#      23     module="pydantic._internal._generate_schema",
#      24 )
#
# File /opt/app-root/lib64/python3.11/site-packages/crewai/rag/chromadb/types.py:6
#       3 from collections.abc import Mapping
#       4 from typing import Any, NamedTuple
# ----> 6 from chromadb.api import AsyncClientAPI, ClientAPI
#       7 from chromadb.api.configuration import CollectionConfigurationInterface
#       8 from chromadb.api.types import (
#       9     CollectionMetadata,
#      10     DataLoader,
#    (...)
#      14     WhereDocument,
#      15 )
#
# File /opt/app-root/lib64/python3.11/site-packages/chromadb/__init__.py:3
#       1 from typing import Dict, Optional
#       2 import logging
# ----> 3 from chromadb.api.client import Client as ClientCreator
#       4 from chromadb.api.client import AdminClient as AdminClientCreator
#       5 from chromadb.api.async_client import AsyncClient as AsyncClientCreator
#
# File /opt/app-root/lib64/python3.11/site-packages/chromadb/api/__init__.py:7
#       5 from overrides import override
#       6 from chromadb.config import DEFAULT_DATABASE, DEFAULT_TENANT
# ----> 7 from chromadb.api.models.Collection import Collection
#       8 from chromadb.api.types import (
#       9     CollectionMetadata,
#      10     Documents,
#    (...)
#      23     WhereDocument,
#      24 )
#      25 from chromadb.config import Component, Settings
#
# File /opt/app-root/lib64/python3.11/site-packages/chromadb/api/models/Collection.py:4
#       1 from typing import TYPE_CHECKING, Optional, Union
#       2 import numpy as np
# ----> 4 from chromadb.api.models.CollectionCommon import CollectionCommon
#       5 from chromadb.api.types import (
#       6     URI,
#       7     CollectionMetadata,
#    (...)
#      19     WhereDocument,
#      20 )
#      22 import logging
#
# File /opt/app-root/lib64/python3.11/site-packages/chromadb/api/models/CollectionCommon.py:14
#      11 import numpy as np
#      12 from uuid import UUID
# ---> 14 import chromadb.utils.embedding_functions as ef
#      15 from chromadb.api.types import (
#      16     URI,
#      17     CollectionMetadata,
#    (...)
#      51     validate_where_document,
#      52 )
#      54 # TODO: We should rename the types in chromadb.types to be Models where
#      55 # appropriate. This will help to distinguish between manipulation objects
#      56 # which are essentially API views. And the actual data models which are
#      57 # stored / retrieved / transmitted.
#
# File /opt/app-root/lib64/python3.11/site-packages/chromadb/utils/embedding_functions/__init__.py:46
#      42                 imported_classes.add(attr.__name__)
#      43     return imported_classes
# ---> 46 _all_classes.update(_import_all_efs())
#      49 # Define and export the default embedding function
#      50 def DefaultEmbeddingFunction() -> Optional[EmbeddingFunction[Documents]]:
#
# File /opt/app-root/lib64/python3.11/site-packages/chromadb/utils/embedding_functions/__init__.py:31, in _import_all_efs()
#      28 if module_name == __name__:
#      29     continue
# ---> 31 module: ModuleType = importlib.import_module(f"{__name__}.{module_name}")
#      33 for attr_name in dir(module):
#      34     attr = getattr(module, attr_name)
#
# File /usr/lib64/python3.11/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File /opt/app-root/lib64/python3.11/site-packages/chromadb/utils/embedding_functions/cloudflare_workers_ai_embedding_function.py:1
# ----> 1 from chromadb.api.types import (
#       2     Embeddings,
#       3     Documents,
#       4     EmbeddingFunction,
#       5     Space,
#       6 )
#       7 from typing import List, Dict, Any, Optional
#       8 import os
#
# ImportError: cannot import name 'Space' from 'chromadb.api.types' (/opt/app-root/lib64/python3.11/site-packages/chromadb/api/types.py)

# %%
def get_base64encoded_image(image_path):
    """Generates a base64-encoded image from the give image path."""
    
    try:
        with open(image_path, "rb") as image_file:
            
            binary_image_data = image_file.read()
            
            base64_encoded_data = base64.b64encode(binary_image_data)
            
            base64_string = base64_encoded_data.decode('utf-8')
            
            return base64_string
            
    except Exception as e:
        print(f"Error occurred while generating base64-encoded image for {image_path}: {e}")
        
        return None

# %%
##############################################################################
# Flows
##############################################################################

class DriversLicenseValidationFlow(Flow):
    """Flow for Driver's License Validation."""

    @start()
    def get_image(self):
        
        print(f"Starting flow {self.state['id']} for {self.state['image_path']}...")

        # image_path = self.state["image_path"]

        # image = get_base64encoded_image(image_path)

        # self.state["image"] = image

    @listen(get_image)
    def validate_image(self):
        
        print("Validating image!...")

        image = self.state["image_path"]

        results = ValidateDriversLicense().crew().kickoff(inputs={"image": image})

        return results

# %% [markdown]
# ### Execute Code Translation Flow
# Execute the flow!

# %%
##############################################################################
# Execute the Flow
##############################################################################
paths = [
    ("https://raw.githubusercontent.com/agapebondservant/dla_poc/refs/heads/main/notebooks/data/DENVER-25CAP-00000-04SUF-ID.jpeg", "data/DENVER-25CAP-00000-04SUF-ID.json")
]

flow = DriversLicenseValidationFlow()

flow.plot("DriversLicenseValidationFlow")

for image_path, application_path in paths:

    results = flow.kickoff(inputs={"image_path": image_path,
                                  "application": application_path})

    if results.json_dict:

        pass
        # print(json.dumps(results.json_dict, indent=2))

    if results.pydantic:

        pass
        
        # print(results.pydantic.model_dump_json(indent=2))

    else:

        pass

        # print(results.raw)

    print("Driver's License Validation flow complete.")
